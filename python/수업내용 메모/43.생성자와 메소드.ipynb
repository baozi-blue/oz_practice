# %%
import os

os.listdir()
# Out:
# ['.config', 'sample_data']

# %%
''' class 클래스 이름:
        def 메소드 이름(self, 추가적인 매개변수)
            pass. '''

# %%
class CreateOzStudent:
    def __init__(self, name, python, database, Django, AWS):
        self.name = name
        self.python = python
        self.database = database
        self.Django = Django
        self.AWS = AWS


# 데이터 입력 : CreateOzStudent() 생성자를 이용해 리스트 안에 데이터 생성
oz_students = [
    CreateOzStudent('Jason', 4, 3, 3, 2),
    CreateOzStudent('Kim', 4, 5, 2, 4),
    CreateOzStudent('Mathew', 3, 4, 4, 1),
    CreateOzStudent('Jane', 2, 3, 1, 5)
]

print(oz_students[0].name)
print(oz_students[0].python)
print(oz_students[0].database)
print(oz_students[0].Django)
print(oz_students[0].AWS)
# Out:
# Jason
# 4
# 3
# 3
# 2

# %%
class CreateOzStudent:
    def __init__(self, name, python, database, Django, AWS):
        self.name = name
        self.python = python
        self.database = database
        self.Django = Django
        self.AWS = AWS

    def get_sum(self):
        return self.python + self.database + self.Django + self.AWS

    def get_avg(self):
        return self.get_sum() / 4

    def get_string(self):
        return f'{self.name}\t{self.get_sum()}\t{self.get_avg()}'


# 데이터 입력 : CreateOzStudent() 생성자를 이용해 리스트 안에 데이터 생성
oz_students = [
    CreateOzStudent('Jason', 4, 3, 3, 2),
    CreateOzStudent('Kim', 4, 5, 2, 4),
    CreateOzStudent('Mathew', 3, 4, 4, 1),
    CreateOzStudent('Jane', 2, 3, 1, 5)
]

print('이름', '총점', '평균', sep="\t")

for student in oz_students:
    print(student.get_string())
# Out:
# 이름	총점	평균
# Jason	12	3.0
# Kim	15	3.75
# Mathew	12	3.0
# Jane	11	2.75
